# %%
# Cell 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib
import json
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

print("✅ Libraries imported successfully")
# Out:
# ✅ Libraries imported successfully

# %%
import sys 
print(sys.executable)
# Out:
# c:\Users\dadia\AppData\Local\Programs\Python\Python313\python.exe

# %%
# Test cell - run this BEFORE your main code
import sys
print(f"Python version: {sys.version}")
print(f"Python path: {sys.executable}")

try:
    import matplotlib
    print("✅ matplotlib installed")
except:
    print("❌ matplotlib NOT installed")

try:
    import prophet
    print("✅ prophet installed")
except:
    print("❌ prophet NOT installed")

print("\nRun this in terminal to install missing packages:")
print("python -m pip install matplotlib seaborn prophet")
# Out:
# Python version: 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
# Python path: c:\Users\dadia\AppData\Local\Programs\Python\Python313\python.exe
# ✅ matplotlib installed
# ✅ prophet installed
#
# Run this in terminal to install missing packages:
# python -m pip install matplotlib seaborn prophet
